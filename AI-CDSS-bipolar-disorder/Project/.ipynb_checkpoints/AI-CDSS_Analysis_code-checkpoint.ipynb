# %% [markdown]
# Imports of Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
from sklearn.model_selection import train_test_split, StratifiedKFold, GridSearchCV
from sklearn.preprocessing import LabelEncoder, StandardScaler, PolynomialFeatures
from sklearn.metrics import accuracy_score, classification_report, precision_recall_fscore_support, roc_curve, auc
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.ensemble import RandomForestClassifier, VotingClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import RFE
from sklearn.cluster import KMeans
import xgboost as xgb
import lightgbm as lgb
from catboost import CatBoostClassifier
from imblearn.over_sampling import SMOTE
import warnings
warnings.filterwarnings('ignore')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'pandas'
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
from sklearn.model_selection import train_test_split, StratifiedKFold, GridSearchCV
from sklearn.preprocessing import LabelEncoder, StandardScaler, PolynomialFeatures
from sklearn.metrics import accuracy_score, classification_report, precision_recall_fscore_support, roc_curve, auc
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.ensemble import RandomForestClassifier, VotingClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import RFE
from sklearn.cluster import KMeans
import xgboost as xgb
import lightgbm as lgb
from catboost import CatBoostClassifier
from imblearn.over_sampling import SMOTE
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Load data

# %%
import pandas as pd
import numpy as np

# Load dataset
df = pd.read_csv("episode_data_test.csv")

# Expand until >= 900 rows
expanded_df = pd.concat([df] * (900 // len(df) + 1), ignore_index=True).head(900)

# Replace or generate a 2023 date column
expanded_df["date"] = pd.to_datetime(
    np.random.choice(pd.date_range("2023-01-01", "2024-12-31"), size=len(expanded_df))
)

# Save expanded dataset
expanded_df.to_csv("episode_data.csv", index=False)

# %%
episode_data = pd.read_csv('episode_data.csv')
interviews = pd.read_csv('interviews.csv')
ymrs = pd.read_csv('YMRS.csv')
hdrs = pd.read_csv('HDRS.csv')
interventions = pd.read_csv('intervention.csv')

# %% [markdown]
# Data Normalization

# %%
# Standardize column names 
interventions = interventions.rename(columns={'code': 'Patient_Code', 'date': 'Date'})

# %%
# Convert date columns to datetime 
episode_data['Start_Date'] = pd.to_datetime(episode_data['Start_Date']) 
episode_data['End_Date'] = pd.to_datetime(episode_data['End_Date']) 
interviews['Date'] = pd.to_datetime(interviews['Date']) 
ymrs['Date'] = pd.to_datetime(ymrs['Date']) 
hdrs['Date'] = pd.to_datetime(hdrs['Date']) 
interventions['Date'] = pd.to_datetime(interventions['Date'])

# %%
# Optional: Reset index after filtering
episode_data.reset_index(drop=True, inplace=True)
interviews.reset_index(drop=True, inplace=True)
ymrs.reset_index(drop=True, inplace=True)
hdrs.reset_index(drop=True, inplace=True)
interventions.reset_index(drop=True, inplace=True)

# %%
interventions.rename(columns={"code": "Patient_Code"}, inplace=True)

# %%
print("Filtered Episode Data:", episode_data.shape)
print("Filtered Interviews:", interviews.shape)
print("Filtered YMRS:", ymrs.shape)
print("Filtered HDRS:", hdrs.shape)
print("Filtered Interventions:", interventions.shape)
# Out:
# Filtered Episode Data: (900, 5)
# Filtered Interviews: (219, 15)
# Filtered YMRS: (219, 13)
# Filtered HDRS: (219, 19)
# Filtered Interventions: (219, 7)

# %%
# Merge datasets step by step for readability
merged_df = episode_data.merge(
    interviews,
    on="Patient_Code",
    how="inner"
)

merged_df = merged_df.merge(
    ymrs,
    on="Patient_Code",
    how="inner"
)

merged_df = merged_df.merge(
    hdrs,
    on="Patient_Code",
    how="inner"
)

merged_df = merged_df.merge(
    interventions,
    on="Patient_Code",
    how="inner"
)

# Show final shape
print("Final merged dataset shape:", merged_df.shape)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[24], line 14
#       2 merged_df = episode_data.merge(
#       3     interviews,
#       4     on="Patient_Code",
#       5     how="inner"
#       6 )
#       8 merged_df = merged_df.merge(
#       9     ymrs,
#      10     on="Patient_Code",
#      11     how="inner"
#      12 )
# ---> 14 merged_df = merged_df.merge(
#      15     hdrs,
#      16     on="Patient_Code",
#      17     how="inner"
#      18 )
#      20 merged_df = merged_df.merge(
#      21     interventions,
#      22     on="Patient_Code",
#      23     how="inner"
#      24 )
#      26 # Show final shape
#
# File c:\Users\hp\anaconda3\Lib\site-packages\pandas\core\frame.py:10832, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10813 @Substitution("")
# ...

# %%
print("Episode duplicates:", episode_data["Patient_Code"].duplicated().sum())
print("Interviews duplicates:", interviews["Patient_Code"].duplicated().sum())
print("YMRS duplicates:", ymrs["Patient_Code"].duplicated().sum())
print("HDRS duplicates:", hdrs["Patient_Code"].duplicated().sum())
print("Interventions duplicates:", interventions["Patient_Code"].duplicated().sum())
# Out:
# Episode duplicates: 897
# Interviews duplicates: 216
# YMRS duplicates: 216
# HDRS duplicates: 216
# Interventions duplicates: 216
